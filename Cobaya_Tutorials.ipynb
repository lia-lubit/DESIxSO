# %%
print('Comment notation:')
print('#: description of what is being done')
print('##: question')
print('###: problem')
print('####: task')

print("github token: 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")
# Out:
# Comment notation:
# #: description of what is being done
# ##: question
# ###: problem
# ####: task
# github token: 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

# %%
# import necessary tools
import sys
#!{sys.executable} -m pip install pyccl
#!{sys.executable} -m pip install camb
import astropy
from astropy.cosmology import LambdaCDM, w0waCDM
import astropy.units as units
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import cm
import numpy as np
import scipy
from scipy.stats import linregress
from IPython.display import display, Math
from scipy.integrate import simpson
from mpl_toolkits.mplot3d import Axes3D
import pylab as pyplt
import pyccl as ccl
import camb
from camb import model, initialpower
import seaborn as sns # Import seaborn
# %matplotlib inline
import cobaya
# %config InlineBackend.figure_format = 'retina'

# %%
# use Cobaya MH MCMC to sample a simple posterior distribution

info = {"likelihood": {
            "gaussian_mixture": { 
                      "means": [0.2, 0],
                #### what form does the cov matrix take? 
                #### how would this look for me?
                       "covs": [[0.1, 0.05], 
                                [0.05, 0.2]],
                        "derived": True}}
        #### what do these different params and priors mean?
        "params": dict([
            ("penguins", {
                "prior": {"min": -0.5, "max": 3}),
                "latex": r"\phi"}),
            ("species", {
                "prior": {"dist": "norm", "loc": 0, "scale": 1},
                "ref": 0, 
                "proposal": 0.5,
                "latex": r"\sigma"}),
            ("hyperparam_penguin", {
                      "latex": r"\phi^\prime"}),
            ("derived_species", {
                      "latex": r"\sigma^\prime"})]),

        "sampler": {...},
        "force": {...},
        "debug": False,
        "output": {...}}
