# %% [markdown]
# <a href="https://colab.research.google.com/github/lia-lubit/DESIxSO/blob/main/forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Comment notation:')
print('#: description of what is being done')
print('##: question')
print('###: problem')
print('####: task')

print("colab link: https://colab.research.google.com/github/lia-lubit/DESIxSO/blob/main/forecasting.ipynb")
# Out:
# Comment notation:
# #: description of what is being done
# ##: question
# ###: problem
# ####: task
# colab link: https://colab.research.google.com/github/lia-lubit/DESIxSO/blob/main/forecasting.ipynb

# %%
#import sys
#!{sys.executable} -m pip install pyccl
#!{sys.executable} -m pip install cosmopower

# %%
# Upgrade numpy to a compatible version
#!pip install numpy --upgrade
# It's also good practice to ensure pandas is up-to-date after numpy upgrade
#!pip install pandas --upgrade
# Out:
# /bin/bash: pip: command not found
# /bin/bash: pip: command not found

# %%
# import tools

# standard library
import os
import sys
import inspect
import yaml
import time

# scientific stack
import numpy as np
import jax.numpy as jnp
import scipy
from scipy.interpolate import interp1d
from scipy.stats import linregress
from scipy.integrate import simpson

# cosmology
import astropy
import astropy.units as units
from astropy.cosmology import LambdaCDM, w0waCDM
import pyccl as ccl
import camb
from camb import model, initialpower
from cosmopower_jax.cosmopower_jax import CosmoPowerJAX as CPJ
# plotting
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import LogNorm
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# inference / sampling
import cobaya
from cobaya.run import run as cobaya_run
from cobaya.likelihood import Likelihood
#from cobaya_utilities import tools -- this wont import, but I don't use it at the momment anyway
import getdist
from getdist import plots, MCSamples
from getdist.mcsamples import loadMCSamples

# notebook only (remove if this becomes a .py module)
# %matplotlib inline

# %%
# import custom helper functions and classes

from functions_and_classes import calculate_and_plot_Cls
from functions_and_classes import build_tracers_from_data
from functions_and_classes import build_tracer_dict
from functions_and_classes import build_noise_dict
from functions_and_classes import build_spectra_dict
from functions_and_classes import create_simplified_desired_pairs
from functions_and_classes import build_covariance_from_data
from functions_and_classes import plot_covariance_matrix
from functions_and_classes import plot_correlation_matrix
from functions_and_classes import plot_spectra_from_dict

from functions_and_classes import ForecastMap
from functions_and_classes import CovarianceMatrix
from functions_and_classes import SO_x_DESI_Likelihood
# Out:
# LOADING FILE: /global/u2/l/lialubit/DESIxSO/functions_and_classes.py

# %%
# data

# DESI-HSC
HSC_dist_0_3 = np.load("data/distributions_0.3_3_vF.npz")
print(f"Keys in distributions_0.3_3_vF.npz: {HSC_dist_0_3.files}")

HSC_dist_1_5 = np.load("data/distributions_1_5_vF.npz")
print(f"Keys in distributions_1_5_vF.npz: {HSC_dist_1_5.files}")

HSC_dist_0_3_a = np.load("data/distributions_0.3_3_vF.npz")['1/nz_mean']
HSC_dist_0_3_b = np.load("data/distributions_0.3_3_vF.npz")['2/nz_mean']
HSC_dist_0_3_c = np.load("data/distributions_0.3_3_vF.npz")['3/nz_mean']
HSC_dist_0_3_d = np.load("data/distributions_0.3_3_vF.npz")['4/nz_mean']
HSC_dist_0_3_z = np.load("data/distributions_0.3_3_vF.npz")['z']
HSC_dist_0_3 = np.column_stack((HSC_dist_0_3_z, HSC_dist_0_3_a, HSC_dist_0_3_b, HSC_dist_0_3_c, HSC_dist_0_3_d)) # make into 2D array for easy processing

HSC_dist_1_5_a = np.load("data/distributions_1_5_vF.npz")['1/nz_mean']
HSC_dist_1_5_b = np.load("data/distributions_1_5_vF.npz")['2/nz_mean']
HSC_dist_1_5_c = np.load("data/distributions_1_5_vF.npz")['3/nz_mean']
HSC_dist_1_5_d = np.load("data/distributions_1_5_vF.npz")['4/nz_mean']
HSC_dist_1_5_z = np.load("data/distributions_1_5_vF.npz")['z']
HSC_dist_1_5 = np.column_stack((HSC_dist_1_5_z, HSC_dist_1_5_a, HSC_dist_1_5_b, HSC_dist_1_5_c, HSC_dist_1_5_d)) # make into 2D array for easy processing

# DESI Lens Data

DESI_lens_data = np.loadtxt("data/des_nz_gamma.txt")

DESI_lens_data = DESI_lens_data[7:]  # removes the first 7 values (headers)
DESI_lens_data = DESI_lens_data.reshape(-1, 6) #shape into array with columns z, nz0 -- nz4

# Split into separate arrays
DESI_lens_z    = DESI_lens_data[:, 0]
DESI_lens_nz_a = DESI_lens_data[:, 1]
DESI_lens_nz_b = DESI_lens_data[:, 2]
DESI_lens_nz_c = DESI_lens_data[:, 3]
DESI_lens_nz_d = DESI_lens_data[:, 4]
DESI_lens_nz_e = DESI_lens_data[:, 5]

DESI_lens_data = np.column_stack((DESI_lens_z, DESI_lens_nz_a, DESI_lens_nz_b, DESI_lens_nz_c, DESI_lens_nz_d))
# Out:
# Keys in distributions_0.3_3_vF.npz: ['z', '1/nz_median', '1/nz_mean', '1/nz_lower', '1/nz_upper', '1/nz_median_mu', '1/nz_mean_mu', '1/nz_lower_mu', '1/nz_upper_mu', '2/nz_median', '2/nz_mean', '2/nz_lower', '2/nz_upper', '2/nz_median_mu', '2/nz_mean_mu', '2/nz_lower_mu', '2/nz_upper_mu', '3/nz_median', '3/nz_mean', '3/nz_lower', '3/nz_upper', '3/nz_median_mu', '3/nz_mean_mu', '3/nz_lower_mu', '3/nz_upper_mu', '4/nz_median', '4/nz_mean', '4/nz_lower', '4/nz_upper', '4/nz_median_mu', '4/nz_mean_mu', '4/nz_lower_mu', '4/nz_upper_mu']
# Keys in distributions_1_5_vF.npz: ['z', '1/nz_median', '1/nz_mean', '1/nz_lower', '1/nz_upper', '1/nz_median_mu', '1/nz_mean_mu', '1/nz_lower_mu', '1/nz_upper_mu', '2/nz_median', '2/nz_mean', '2/nz_lower', '2/nz_upper', '2/nz_median_mu', '2/nz_mean_mu', '2/nz_lower_mu', '2/nz_upper_mu', '3/nz_median', '3/nz_mean', '3/nz_lower', '3/nz_upper', '3/nz_median_mu', '3/nz_mean_mu', '3/nz_lower_mu', '3/nz_upper_mu', '4/nz_median', '4/nz_mean', '4/nz_lower', '4/nz_upper', '4/nz_median_mu', '4/nz_mean_mu', '4/nz_lower_mu', '4/nz_upper_mu']

# %%
# graph HSC source distributions

plt.figure(figsize=(10, 6))
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_a, label='Bin 1')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_b, label='Bin 2')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_c, label='Bin 3')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_d, label='Bin 4')
plt.xlabel('Redshift (z)')
plt.ylabel('Normalized Redshift Distribution ($n_s$)')
plt.title('HSC_dist_0_3 Redshift Distributions ($n_s$)')
plt.legend()
plt.grid(True)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Liberation Serif'
plt.rcParams['font.size'] = 14
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(HSC_dist_1_5_z, HSC_dist_1_5_a, label='Bin 1')
plt.plot(HSC_dist_1_5_z, HSC_dist_1_5_b, label='Bin 2')
plt.plot(HSC_dist_1_5_z, HSC_dist_1_5_c, label='Bin 3')
plt.plot(HSC_dist_1_5_z, HSC_dist_1_5_d, label='Bin 4')
plt.xlabel('Redshift (z)')
plt.ylabel('Normalized Redshift Distribution ($n_s$)')
plt.title('HSC_dist_1_5 Redshift Distributions ($n_s$)')
plt.legend()
plt.grid(True)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Liberation Serif'
plt.rcParams['font.size'] = 14
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(DESI_lens_z, DESI_lens_nz_a, label='Bin 1')
plt.plot(DESI_lens_z, DESI_lens_nz_b, label='Bin 2')
plt.plot(DESI_lens_z, DESI_lens_nz_c, label='Bin 3')
plt.plot(DESI_lens_z, DESI_lens_nz_d, label='Bin 4')
#plt.plot(DESI_lens_z, DESI_lens_nz_e, label='Bin 5')
#### nz_5 has values all of order e7 or above,
#### while the others have values of order e-5 or below
#### what's going on here?
plt.xlabel('Redshift (z)')
plt.ylabel('Normalized Redshift Distribution ($n_s$)')
plt.title('DESI Lens Redshift Distributions ($n_s$)')
plt.legend()
plt.grid(True)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Liberation Serif'
plt.rcParams['font.size'] = 14
plt.show()

# %%
# calculate mean lens redshifts for each DESI lens bin
mean_desi_lens_redshifts = []

# DESI_lens_data contains z in col 0, then nz_a, nz_b, nz_c, nz_d in cols 1-4
nz_arrays_desi = [DESI_lens_nz_a, DESI_lens_nz_b, DESI_lens_nz_c, DESI_lens_nz_d]
z_lens_grid = DESI_lens_data[:, 0]

for i, n_lens_i in enumerate(nz_arrays_desi):
    if np.sum(n_lens_i) == 0:
        mean_desi_lens_redshifts.append(np.nan)
    else:
        z_l_i = scipy.integrate.trapezoid(z_lens_grid * n_lens_i, z_lens_grid) / scipy.integrate.trapezoid(n_lens_i, z_lens_grid)
        mean_desi_lens_redshifts.append(z_l_i)

print("Mean redshifts for DESI lens bins:")
for i, z_l_i in enumerate(mean_desi_lens_redshifts):
    print(f"  Lens Bin {i+1}: {z_l_i:.3f}")

# plot DESI lens distributions and the first HSC_dist_0_3 source distribution
plt.figure(figsize=(10, 6))
plt.plot(DESI_lens_z, DESI_lens_nz_a, label='DESI Lens Bin 1')
plt.plot(DESI_lens_z, DESI_lens_nz_b, label='DESI Lens Bin 2')
plt.plot(DESI_lens_z, DESI_lens_nz_c, label='DESI Lens Bin 3')
plt.plot(DESI_lens_z, DESI_lens_nz_d, label='DESI Lens Bin 4')

plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_a, label='HSC Source Bin 1', linestyle='-', linewidth=1, color='black')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_b, label='HSC Source Bin 2', linestyle='-', linewidth=1, color='purple')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_c, label='HSC Source Bin 3', linestyle='-', linewidth=1, color='blue')
plt.plot(HSC_dist_0_3_z, HSC_dist_0_3_d, label='HSC Source Bin 4', linestyle='-', linewidth=1, color='gray')

# Add vertical lines for mean lens redshifts
for i, z_l_i in enumerate(mean_desi_lens_redshifts):
    plt.axvline(x=z_l_i, color=f'C{i}', linestyle='--', label=f'Mean Lens Z Bin {i+1} ({z_l_i:.2f})')

plt.xlabel('Redshift (z)')
plt.ylabel('Normalized Redshift Distribution (n(z))')
plt.title('DESI Lens and HSC Source Redshift Distributions')
plt.legend()
plt.grid(True)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Liberation Serif'
plt.rcParams['font.size'] = 14
plt.show()
# Out:
# Mean redshifts for DESI lens bins:
#   Lens Bin 1: 0.343
#   Lens Bin 2: 0.522
#   Lens Bin 3: 0.742
#   Lens Bin 4: 0.936

# %%
# CCL
print('CCL cosmology parameters:')
print('Omega_c: the density fraction at z=0 of CDM.')
print('Omega_b: the density fraction at z=0 of baryons.')
print('h: the Hubble constant in units of 100 k⁢m/s/M⁢p⁢c.')
print('Omega_k: the curvature density fraction at 𝑧 =0.')
print('Omega_g: the density of radiation (not including massless neutrinos.')
print('w0: first order term of the dark energy equation of state.')
print('wa: second order term of the dark energy equation of state.')
# Out:
# CCL cosmology parameters:
# Omega_c: the density fraction at z=0 of CDM.
# Omega_b: the density fraction at z=0 of baryons.
# h: the Hubble constant in units of 100 k⁢m/s/M⁢p⁢c.
# Omega_k: the curvature density fraction at 𝑧 =0.
# Omega_g: the density of radiation (not including massless neutrinos.
# w0: first order term of the dark energy equation of state.
# wa: second order term of the dark energy equation of state.

# %%
# CCL cosmolgoies

# сosmology -- standard CCL + DESI waw0
h = 0.6674
w0 = -0.752
wa = -0.86
Om0 = 0.3191
Omega_c = 0.27
Omega_b = 0.045
sigma8 = 0.8
n_s = 0.96
w0wa_cosmology = ccl.Cosmology(Omega_c=Omega_c, Omega_b=Omega_b, h=h, sigma8=sigma8,
                               n_s=n_s, w0=w0, wa=wa, transfer_function='bbks')

# сosmology -- standard CCL + DESI curved h and Omega_k
h = 0.6850
Om0 = 0.3191
Omega_c = 0.27
Omega_b = 0.045
sigma8 = 0.8
n_s = 0.96
Omega_k = 2.3e-3
curved_LCDM_cosmology = ccl.Cosmology(Omega_k = Omega_k, Omega_c=Omega_c, Omega_b=Omega_b, h=h, sigma8=sigma8,
                               n_s=n_s, transfer_function='bbks')

# cosmology -- standard CCL + flat LCDM
z_star = 1100.0
Om0 = 0.3027   # matter density
H0 = 68.17     # Hubble [km/s/Mpc]
Ode0 = 1 - Om0 # dark energy density
Omega_k = 0
Omega_b = 0.045
Omega_c = 0.27
flat_LCDM_cosmology = ccl.Cosmology(Omega_k = Omega_k, Omega_c=Omega_c, Omega_b=Omega_b, h=h, sigma8=sigma8,
                               n_s=n_s, transfer_function='bbks')

# %%
# plot angular power spectra

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['LL'])

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['GG'])

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['GL'])

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['CL'])

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['CG'])

calculate_and_plot_Cls(
    cosmology=flat_LCDM_cosmology,
    lens_data=DESI_lens_data,
    source_data=HSC_dist_0_3,
    correlation_types=['CC'])

# %% [markdown]
# The covariance matrix is rather complicated because we have many different types of data for which we need to consider the covariances. We'll set up the data vector:
#
# $$\mathbf{D} = [C_\ell^{\kappa\kappa}, C_\ell^{gg}, C_\ell^{\gamma\gamma}, C_\ell^{g\gamma}, C_\ell^{g\kappa}, C_\ell^{\gamma\kappa}]$$
#
# This vector consists of:
# * **CMB lensing convergence power spectrum:** $C_\ell^{\kappa\kappa}$
# * **Lens galaxies auto/cross-spectrum:** $C_\ell^{gg}$ (galaxy clustering)
# * **Galaxy lensing auto/cross-spectrum:** $C_\ell^{\gamma\gamma}$ (cosmic shear)
# * **Lens galaxy-galaxy lensing cross-spectrum:** $C_\ell^{g\gamma}$ (galaxy-galaxy lensing)
# * **Lens galaxies–CMB lensing cross-spectrum:** $C_\ell^{g\kappa}$
# * **Galaxy lensing–CMB lensing cross-spectrum:** $C_\ell^{\gamma\kappa}$
#
# If we have **a** lens bins and **b** source bins we have 1 CMB, $\frac{a(a+1)}{2}$ lens-lens, $\frac{b(b+1)}{2}$ source-source, ab lens-source, a lens-CMB, and b source-CMB spectra. Each component is a list with $N_l$ entries.
#
# The covariance matrix includes the covariances of all spectra with all other spectra. This means that it is a massive block matrix, with each block being an $N_\ell \times N_\ell$ matrix.
#
# $$\text{Cov}_{\text{master }}[i,j] = \text{Cov}(D_i, D_j)$$
# $$\mathrm{Cov}(C^{ab}_{\ell}, C^{cd}_{\ell'}) = \frac{\delta_{\ell \ell'}}{(2\ell + 1)\, f_{\mathrm{sky}}} \left( C^{ac}_\ell C^{bd}_\ell + C^{ad}_\ell C^{bc}_\ell \right)$$
#
# In order to do a proper MCMC, we will need to calculate the entries in the master covariance matrix and input it into Cobaya.
#
# Note that calculating covariances will be a little tricky because we'll need the computer to figure out what spectra are being considered, separate out their variables, swap them around, and then locate the correct spectra for the product terms.

# %%
# build DESI, SO noise, and magnification
# shot noise ref: https://arxiv.org/pdf/2407.04607
# shape noise ref: slack from Simone, can't find the Github itself
# SO noise ref:
# magnification ref: https://arxiv.org/pdf/2503.24385

sigma = 0.26
DESI_n_bar_deg2 = np.array([81.9, 148.1, 162.4, 148.3]) # Galaxies per square degree

# Convert n_bar from per deg^2 to per steradian
# 1 steradian = (180/pi)^2 square degrees
DESI_n_bar_steradian = DESI_n_bar_deg2 * (180.0 / np.pi)**2

DESI_shot_noise = np.zeros_like(DESI_n_bar_steradian)
DESI_shape_noise = np.zeros_like(DESI_n_bar_steradian)
for i in range(len(DESI_shot_noise)):
    DESI_shot_noise[i] = 1 / DESI_n_bar_steradian[i]
    DESI_shape_noise[i] = sigma ** 2 / DESI_n_bar_steradian[i]

# CMB noise arises from idk a bunch of stuff
# we have an SO noise curve, but it does not have precisely the same ells as our C_l
# we must interpolate the N_kk to produce a useful noise curve
SO_noise_data = np.genfromtxt("data/nlkk_v3_1_0deproj0_SENS2_fsky0p4_it_lT30-3000_lP30-5000.dat")
S_noise_ells = SO_noise_data[:, 0]
N_kk = SO_noise_data[:, 7]
ells_for_noise_interp = np.arange(2, 3000 + 2) # Assuming n_ell = 3000 as used in examples

# Use fill_value=(N_kk[0], N_kk[-1]) to cap the noise at the boundaries
interpolated_N_kk_func = interp1d(S_noise_ells, N_kk, bounds_error=False, fill_value=(N_kk[0], N_kk[-1]))
SO_CMB_noise = interpolated_N_kk_func(ells_for_noise_interp)
# Handle potential negative noise if for some reason the source data contains them, set to a small positive number
SO_CMB_noise[SO_CMB_noise < 0] = 1e-30 # Or whatever appropriate small value

# save
# make sure folder exists
os.makedirs("data", exist_ok=True)
np.save("data/SO_CMB_noise.npy", SO_CMB_noise)
print("Saved SO_CMB_noise to data/SO_CMB_noise.npy")
# Out:
# Saved SO_CMB_noise to data/SO_CMB_noise.npy

# %%
# plot N_kk to see what it looks like

plt.figure(figsize=(10, 6))
plt.loglog(S_noise_ells, N_kk, label='N_kk (Original CMB Noise)')
plt.loglog(ells_for_noise_interp, SO_CMB_noise, label='N_kk (Interpolated CMB Noise)', linestyle='--')
plt.xlabel('Multipole, $\ell$')
plt.ylabel('Noise Power Spectrum, $N_{\ell}^{\kappa\kappa}$ ($N_{kk}$)')
plt.title('CMB Lensing Noise Spectrum ($N_{kk}$)')
plt.axvline(x=3000, color='red', linestyle='--', label='$\ell = 3000$') # Added vertical line
plt.legend()
plt.grid(True, which="both", ls="-")
plt.tight_layout()
plt.show()

# %%
# example without noise

# build the matrix!
CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map = build_covariance_from_data(flat_LCDM_cosmology, DESI_lens_data, HSC_dist_0_3, f_sky=0.4, n_ell=3000, binsize=50, desired_spectra=['CG', 'GL'], magnification_bias_lenses = 0.8)

# plot the noiseless spectra
# Get the desired pairs for CG and GL
cg_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])
gl_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])

#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Noiseless Angular Power Spectrum', desired_spectra=cg_pairs)
#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Noiseless Angular Power Spectrum', desired_spectra=gl_pairs)

# Pass binsize to plotting functions as well
plot_covariance_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])
noiseless_corr_matrix = plot_correlation_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])

#non_zero = noiseless_corr_matrix[noiseless_corr_matrix != 0]
#min_val = np.min(non_zero)
#print("The lowest non-zero correlation is: ", min_val)

# %%
# example with noise

# build the matrix!
CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map = build_covariance_from_data(flat_LCDM_cosmology, DESI_lens_data, HSC_dist_0_3, f_sky=0.4, n_ell=3000, binsize=50, desired_spectra=['CG', 'GL'], shot_noise_lens = DESI_shot_noise, shape_noise_source = DESI_shape_noise, cmb_noise_kappa = SO_CMB_noise, magnification_bias_lenses = 0.8)

# plot the noisy spectra
# Get the desired pairs for CG and GL
cg_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])
gl_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])

#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Noisy Angular Power Spectrum', desired_spectra=cg_pairs)
#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Noisy Angular Power Spectrum', desired_spectra=gl_pairs)

# Pass binsize to plotting functions as well
#plot_covariance_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])
#noisy_corr_matrix = plot_correlation_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])

# what is the lowest non-zero value in the noisy matrix? -- that is, what are those tiny non-zero correlations we see?
#non_zero = noisy_corr_matrix[noisy_corr_matrix != 0]
#min_val = np.min(non_zero)
#print("The lowest non-zero correlation is: ", min_val)

# %%
# plot with artificially reduced noise to check that the noise function is working
# build DESI, SO noise, and magnification
# shot noise ref: https://arxiv.org/pdf/2407.04607
# shape noise ref: slack from Simone, can't find the Github itself
# SO noise ref:
# magnification ref: https://arxiv.org/pdf/2503.24385

#sigma = 0.26
#DESI_n_bar_deg2 = np.array([81.9, 148.1, 162.4, 148.3]) # Galaxies per square degree

# Convert n_bar from per deg^2 to per steradian
# 1 steradian = (180/pi)^2 square degrees
#DESI_n_bar_steradian = DESI_n_bar_deg2 * (180.0 / np.pi)**2

#DESI_mini_shot_noise = np.zeros_like(DESI_n_bar_steradian)
#DESI_mini_shape_noise = np.zeros_like(DESI_n_bar_steradian)
#for i in range(len(DESI_shot_noise)):
#    DESI_mini_shot_noise[i] = 1 / (100000000 * DESI_n_bar_steradian[i])
#    DESI_mini_shape_noise[i] = sigma ** 2 / (100000000 * DESI_n_bar_steradian[i])

# CMB noise arises from idk a bunch of stuff
# we have an SO noise curve, but it does not have precisely the same ells as our C_l
# we must interpolate the N_kk to produce a useful noise curve
#SO_noise_data = np.genfromtxt("data/nlkk_v3_1_0deproj0_SENS2_fsky0p4_it_lT30-3000_lP30-5000.dat")
#S_noise_ells = SO_noise_data[:, 0]
#N_kk = SO_noise_data[:, 7]
#ells_for_noise_interp = np.arange(2, 3000 + 2) # Assuming n_ell = 3000 as used in examples

# Use fill_value=(N_kk[0], N_kk[-1]) to cap the noise at the boundaries
#interpolated_N_kk_func = interp1d(S_noise_ells, N_kk, bounds_error=False, fill_value=(N_kk[0], N_kk[-1]))
#SO_CMB_noise = interpolated_N_kk_func(ells_for_noise_interp) / 100000000
# Handle potential negative noise if for some reason the source data contains them, set to a small positive number
#SO_CMB_noise[SO_CMB_noise < 0] = 1e-30 # Or whatever appropriate small value

# example with noise

# build the matrix!
#CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map = build_covariance_from_data(flat_LCDM_cosmology, DESI_lens_data, HSC_dist_0_3, f_sky=0.4, n_ell=3000, binsize=50, desired_spectra=['CG', 'GL'], shot_noise_lens = DESI_mini_shot_noise, shape_noise_source = DESI_mini_shape_noise, cmb_noise_kappa = SO_CMB_noise, magnification_bias_lenses = 0.8)

# plot the noisy spectra
# Get the desired pairs for CG and GL
#cg_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])
#gl_pairs = create_simplified_desired_pairs(DESI_lens_data.shape[1]-1, HSC_dist_0_3.shape[1]-1, ['CC', 'LL', 'GG'])

#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Semi-Noisy Angular Power Spectrum', desired_spectra=cg_pairs)
#plot_spectra_from_dict(CG_GL_spectra_dict, title_prefix='Semi-Noisy Angular Power Spectrum', desired_spectra=gl_pairs)

# Pass binsize to plotting functions as well
#plot_covariance_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])
#plot_correlation_matrix(CG_GL_cov, CG_GL_spectra_dict, CG_GL_f_map, binsize=50, desired_spectra=['CG', 'GL'])

# %%
print("Note: The noisy correlation matrix is almost exclusively diagonal, but there are some non-zero off-diagonal components.")
print("They start around order 10^-7. By comparison, the noiseless correlation matrix has a lowest-non-zero value of 0.0602.")
print("I checked this to make sure that the tiny things I was seeing were true components of the noisy correlation matrix,")
print("and not just other artifacts that were also present in the noiseless matrix.)")
# Out:
# Note: The noisy correlation matrix is almost exclusively diagonal, but there are some non-zero off-diagonal components.
# They start around order 10^-7. By comparison, the noiseless correlation matrix has a lowest-non-zero value of 0.0602.
# I checked this to make sure that the tiny things I was seeing were true components of the noisy correlation matrix,
# and not just other artifacts that were also present in the noiseless matrix.)

# %% [markdown]
# ### CosmoPower Emulator
#
# **CosmoPower** is a suite of neural network emulators that can predict power spectra and other parameters. In MCMC, a lot of the computation time is spent calculating power spectra for each proposed set of cosmological parameters. Cosmopower can speed this up.
#
# We'll do some experimenting with CosmoPower and then integrate it with the MCMC.
#
# What we need to do is:
# 1. Before running the MCMC, train the network on a dataset of power spectra computed using a full Boltzmann solver across a wide range of cosmological parameters, or find a pre-trained model and extrapolate from it to get the spectra we want.
# 2. Integrate the CosmoPower network into the Cobaya likelihood. That way, during the sampling, instead of recalculating the power spectru at each step, the pre-trained CosmoPower network will rapidly predict the power spectra. This will allow the sampler to explore much more quickly.
#
# We'll need:
# 1.  **`cosmopower`**: The core library containing the trained emulators.
# 2.  **`cobaya-cosmopower`**: A Cobaya-specific wrapper that integrates the `cosmopower_cl` likelihood into your Cobaya runs. We'll specify a path to a pre-trained CosmoPower model (`.npz` file) for the desired power spectra (e.g., `cl_TT`, `cl_EE`, `cl_TE`, `cl_kappa_kappa`). This will repalce our current call to pyccl.
#
# Notes:
# 1. The emulator has a k-grid but NOT a z-grid. You can dynaically set the z values and run the emulator. Our C_l's are all integrals over the line of sight (over lots of different z's) so we'll need to consider the P(k) at all the z's from here to the start of time. We'll need to figure out if that z range is suitable for all the calculations -- I need to get more into the details of the integrals of C_l's again for the different types of C_l.
# 2. The standard CosmoPower uses TensorFlow which is incompatible with other packages we need. Use CosmoPower-Jax instead. (Trust me on this, don't try to make the normal CosmoPower work...)

# %%
# CosmoPower-Jax test

# omega_b, omega_cdm, h, tau, n_s, ln10^10A_s
cosmo_params = np.array([0.025, 0.11, 0.68, 0.1, 0.97, 3.1])
emulator = CPJ(probe='cmb_tt')
emulator_predictions = emulator.predict(cosmo_params)
ell_modes = emulator.modes
print('ell_modes: ', ell_modes)
print('C_l^TT: ', emulator_predictions)

# plot 1
fig = plt.figure(figsize=(20,10))
pred = emulator_predictions[0]*ell_modes*(ell_modes+1)/(2.*np.pi)
plt.loglog(ell_modes, emulator_predictions, 'blue', label='COSMOPOWER PCAplusNN', linewidth=5, linestyle='--')
plt.xlabel('$\ell$', fontsize='30')
plt.ylabel('$\\frac{\ell(\ell+1)}{2 \pi} C_\ell$', fontsize='30')
plt.legend(fontsize=20)

#plot 2
fig = plt.figure(figsize=(20, 10))
dimensionless_cl = emulator_predictions
# convert to standard D_l in units of uK^2
T_cmb = 2.7255e6  # CMB temperature in micro-Kelvin
dl_tt = dimensionless_cl * (ell_modes * (ell_modes + 1) / (2. * np.pi)) * (T_cmb**2)

plt.semilogx(ell_modes, dl_tt, 'blue', label='COSMOPOWER PCAplusNN', linewidth=5, linestyle='--')
plt.xlabel(r'$\ell$', fontsize=30)
plt.ylabel(r'$D_\ell^{TT} \ [\mu\text{K}^2]$', fontsize=30)
plt.xlim(2, max(ell_modes))
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend(fontsize=20)
plt.tick_params(labelsize=18)
plt.show()
# Out:
# ell_modes:  [   2    3    4 ... 2506 2507 2508]
# C_l^TT:  [1.5674932e-10 7.3293843e-11 4.1095505e-11 ... 1.1857567e-17 1.1811569e-17
#  1.1766628e-17]

# %%
#import pre-trained P(k) emulators stored in emulator file

lin_emu = CPJ(probe='mpk_lin')
nlboost_emu = CPJ(probe='mpk_boost')

print('linear P(k) emulator parameters: ', lin_emu.parameters)
print('non-linear P(k) emulator parameters: ', nlboost_emu.parameters)
# Out:
# linear P(k) emulator parameters:  ['omega_b', 'omega_cdm', 'h', 'n_s', 'ln10^{10}A_s', 'z']
# non-linear P(k) emulator parameters:  ['omega_b', 'omega_cdm', 'h', 'n_s', 'ln10^{10}A_s', 'cmin', 'eta_0', 'z']

# %%
# test P(k) emulator

# emulator
params = {
    'omega_b': np.array([0.0225]),
    'omega_cdm': np.array([0.113]),
    'h': np.array([0.7]),
    'n_s': np.array([0.96]),
    'ln10^{10}A_s': np.array([3.07]),
    'z': np.array([0.5]),
}

spectrum_cosmopower = lin_emu.predict(params)
k_modes = lin_emu.modes

# PyCCL
h = 0.7
Omega_b = 0.0225 / (h**2)
Omega_c = 0.113 / (h**2)
n_s = 0.96
cosmo_ccl = ccl.Cosmology(
    Omega_c=Omega_c, 
    Omega_b=Omega_b, 
    h=h, 
    n_s=n_s,
    A_s=np.exp(3.07) / 1e10, # Convert ln10^10As back to raw A_s
    transfer_function='boltzmann_camb' # Use a real boltzmann solver baseline
)

# get P(k) from CCL at z=0.5
# note: pyccl uses scale factor a = 1 / (1 + z)
a = 1.0 / (1.0 + 0.5)
spectrum_ccl = ccl.linear_matter_power(cosmo_ccl, k_modes, a)

# log plot plot
pred = spectrum_cosmopower
true = spectrum_ccl
fig = plt.figure(figsize=(20, 10))
plt.loglog(k_modes, true, 'red', linewidth=5, label='CCL (Boltzmann)')
plt.loglog(k_modes, pred, 'blue', label='COSMOPOWER NN', linewidth=5, linestyle='--')
plt.xlabel('$k$ [Mpc$^{-1}$]', fontsize=20)
plt.ylabel('$P_{\mathrm{LIN}}(k) [\mathrm{Mpc}^3]$', fontsize=20)
plt.grid(True, which="both", ls="--", alpha=0.5)
plt.legend(fontsize=20)
plt.tick_params(labelsize=16)
plt.show()

# %%
# now we need to build a general structure to get from P(k) to the C_l's we need

# %%
# get ln(10^{10}A_s) from the cosmology -- our inputs have sigma8, not A_s

def get_ln10_10_As(Omega_c, Omega_b, h, n_s, sigma8, transfer_function='bbks', matter_power_spectrum='linear'):
    # Create a temporary CCL cosmology to get A_s for a given sigma8
    temp_ccl_cosmo = ccl.Cosmology(
        Omega_c=Omega_c,
        Omega_b=Omega_b,
        h=h,
        n_s=n_s,
        sigma8=sigma8,
        transfer_function=transfer_function,
        matter_power_spectrum=matter_power_spectrum
    )
    A_s_val = temp_ccl_cosmo.cosmo.params.A_s
    return np.log(A_s_val * 1e10)

# %%
# convert the P(k) emulator into a P(k) that can be passed to PyCCL

# create an EmulatorHandler class
class PkEmulatorHandler:
    def __init__(self, emulator_nn_instance, k_arr_for_ccl, z_arr_for_ccl):
        self.emulator = emulator_nn_instance
        self.k_arr_for_ccl = k_arr_for_ccl # This is the k-grid we want CCL to use

        # Determine the k-grid the emulator outputs predictions for (its native k-grid)
        # This MUST correspond to the second dimension of the emulator's predict output.
        emulator_native_k_arr_candidate = None

        if hasattr(self.emulator, 'modes') and self.emulator.modes is not None:
            emulator_native_k_arr_candidate = np.asarray(self.emulator.modes)

        elif hasattr(self.emulator, 'k_samples') and self.emulator.k_samples is not None:
            emulator_native_k_arr_candidate = np.asarray(self.emulator.k_samples)

        elif hasattr(self.emulator, '_k_grid') and self.emulator._k_grid is not None:
            emulator_native_k_arr_candidate = np.exp(np.asarray(self.emulator._k_grid))

        else:
            raise AttributeError("Could not determine emulator native k-grid.")
    
        if emulator_native_k_arr_candidate is None:
            # If we cannot determine the emulator's native k-grid from its attributes,
            # we raise an error. The PkEmulatorHandler cannot function if it doesn't know
            # the k-grid that the emulator is supposed to output on.
            raise AttributeError("Could not determine emulator's native output k-grid. "
                                 "Please ensure the emulator instance (e.g., CosmoPowerJAX) "
                                 "has a 'k_samples' attribute or a '_k_grid' attribute that is not None and not empty. "
                                 "Without this information, the PkEmulatorHandler cannot correctly map emulator output to k values for interpolation.")
        self.emulator_native_k_arr = emulator_native_k_arr_candidate

        # Store the original z_arr, ensuring it's ascending for emulator input
        self._emulator_z_arr = np.sort(z_arr_for_ccl)
        # Store z_arr for CCL, which needs to be descending to make a_arr ascending
        self._ccl_z_arr = np.sort(z_arr_for_ccl)[::-1] # This is DESCENDING z

    def get_Pk2D_object(self, cosmo_params_dict):
        base_params = np.array([
            cosmo_params_dict['omega_b'],
            cosmo_params_dict['omega_cdm'],
            cosmo_params_dict['h'],
            cosmo_params_dict['n_s'],
            cosmo_params_dict['ln10^{10}A_s']
        ])

        emulator_input = np.vstack([
            np.append(base_params, z_val) for z_val in self._emulator_z_arr
        ])

        pk_emulated_output = self.emulator.predict(emulator_input)
        # pk_emulated_output shape should be (len(self._emulator_z_arr), len(self.emulator_native_k_arr))

        # Check if the dimensions are consistent before interpolation
        if pk_emulated_output.shape[1] != len(self.emulator_native_k_arr):
            raise ValueError("Emulator's predict output k-dimension does not match "
                             "the inferred emulator_native_k_arr length. "
                             f"Expected {len(self.emulator_native_k_arr)}, got {pk_emulated_output.shape[1]}. "
                             "This indicates a fundamental inconsistency between the emulator's stated k-grid "
                             "and its actual output. Please check the emulator's configuration.")

        # Interpolate each redshift slice onto the desired k_arr_for_ccl
        pk_interpolated_for_ccl = np.zeros((len(self._emulator_z_arr), len(self.k_arr_for_ccl)))

        min_emu_k = self.emulator_native_k_arr.min()
        max_emu_k = self.emulator_native_k_arr.max()
        min_ccl_k = self.k_arr_for_ccl.min() 
        max_ccl_k = self.k_arr_for_ccl.max()

        if min_ccl_k < min_emu_k or max_ccl_k > max_emu_k:
            print(f"WARNING: k_arr_for_ccl range [{min_ccl_k:.2e}, {max_ccl_k:.2e}] extends beyond "
                  f"emulator's native output k-range [{min_emu_k:.2e}, {max_emu_k:.2e}]. "
                  "Extrapolation will be used by `interp1d`, which might be inaccurate.")

        for i in range(len(self._emulator_z_arr)):
            interp_func = interp1d(self.emulator_native_k_arr, pk_emulated_output[i, :],
                                   kind='linear', bounds_error=False, fill_value="extrapolate")
            pk_interpolated_for_ccl[i, :] = interp_func(self.k_arr_for_ccl)

        pk_interpolated_for_ccl[pk_interpolated_for_ccl <= 0] = 1e-30

        pk_mm_values_for_ccl = pk_interpolated_for_ccl[::-1, :]

        pk_object = ccl.Pk2D(
            a_arr=1.0/(1.0+self._ccl_z_arr),
            lk_arr=np.log(self.k_arr_for_ccl),
            pk_arr=np.log(pk_mm_values_for_ccl),
            is_logp=True
        )
        return pk_object

# %%
# generate P(k) using emulator given flat LCDM, and create a PyCCL cosmology with the custom P(k)

# instantiate the PkEmulatorHandler
cp_emulator_pk_mm = PkEmulatorHandler(lin_emu, pk_k_arr_global, pk_z_arr_global)
print("CosmoPower P(k) emulator handler instantiated.")

# define cosmological parameters for the emulator using flat_LCDM_cosmology as a base
cp_cosmo_params = {
    'Omega_c': flat_LCDM_cosmology['Omega_c'],
    'Omega_b': flat_LCDM_cosmology['Omega_b'],
    'h': flat_LCDM_cosmology['h'],
    'n_s': flat_LCDM_cosmology['n_s'],
    'sigma8': flat_LCDM_cosmology['sigma8'] # sigma8 will be converted to ln10^{10}A_s
}

# get ln10^{10}A_s for the emulator
ln10_10_As_for_emulator = get_ln10_10_As(
    Omega_c=cp_cosmo_params['Omega_c'],
    Omega_b=cp_cosmo_params['Omega_b'],
    h=cp_cosmo_params['h'],
    n_s=cp_cosmo_params['n_s'],
    sigma8=cp_cosmo_params['sigma8']
)

# parameters for the emulator's predict method
num_z = len(pk_z_arr_global)
emulator_input_params = {
    'omega_b': cp_cosmo_params['Omega_b'],
    'omega_cdm': cp_cosmo_params['Omega_c'],
    'h': cp_cosmo_params['h'],
    'n_s': cp_cosmo_params['n_s'],
    'ln10^{10}A_s': ln10_10_As_for_emulator,
    'z': jnp.array(pk_z_arr_global)
}

# get the Pk2D object from the emulator
pk_from_emulator = cp_emulator_pk_mm.get_Pk2D_object(emulator_input_params)

# create a CCL cosmology object that uses the emulated Pk2D
emulated_ccl_cosmology = ccl.Cosmology(
    Omega_c=cp_cosmo_params['Omega_c'],
    Omega_b=cp_cosmo_params['Omega_b'],
    h=cp_cosmo_params['h'],
    n_s=cp_cosmo_params['n_s'],
    sigma8=cp_cosmo_params['sigma8'], # keep sigma8 for other CCL calculations
    transfer_function='bbks', # use 'bbks' or match emulator training
    matter_power_spectrum=pk_from_emulator # inject the emulated Pk2D
)

print("Emulated P(k) obtained and integrated into a CCL Cosmology object.")
# Out:
# CosmoPower P(k) emulator handler instantiated.
# WARNING: k_arr_for_ccl range [1.00e-04, 1.00e+01] extends beyond emulator's native output k-range [1.00e-05, 9.81e+00]. Extrapolation will be used by `interp1d`, which might be inaccurate.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 40
#      36 # get the Pk2D object from the emulator
#      37 pk_from_emulator = cp_emulator_pk_mm.get_Pk2D_object(emulator_input_params)
#      38
#      39 # create a CCL cosmology object that uses the emulated Pk2D
# ---> 40 emulated_ccl_cosmology = ccl.Cosmology(
#      41     Omega_c=cp_cosmo_params['Omega_c'],
#      42     Omega_b=cp_cosmo_params['Omega_b'],
#      43     h=cp_cosmo_params['h'],
#
# File ~/.conda/envs/cosmo311/lib/python3.11/site-packages/pyccl/cosmology.py:271, in Cosmology.__init__(self, Omega_c, Omega_b, h, n_s, sigma8, A_s, Omega_k, Omega_g, Neff, m_nu, mass_split, w0, wa, T_CMB, T_ncdm, transfer_function, matter_power_spectrum, baryonic_effects, mg_parametrization, extra_parameters)
#     269     self.matter_power_spectrum_type = matter_power_spectrum
#     270 else:
# --> 271     raise ValueError(f"matter_power_spectrum={matter_power_spectrum} "
#     272                      f"not supported.")
#     274 self.baryons = baryonic_effects
#     275 if not isinstance(self.baryons, baryons.Baryons):
#
# ValueError: matter_power_spectrum=<pyccl.pk2d.Pk2D>
# 	+==============+=================================================================+
# 	| a \ log10(k) | -4.00e+00 -3.97e+00 -3.95e+00 ...  9.50e-01  9.75e-01  1.00e+00 |
# 	+==============+=================================================================+
# 	|  9.08e-04    |       nan       nan       nan ...       nan       nan       nan |
# 	|  9.08e-04    |       nan       nan       nan ...       nan       nan       nan |
# 	|  9.08e-04    |       nan       nan       nan ...       nan       nan       nan |
# 	|     ...      |                               ...                               |
# 	|  8.20e-01    |       nan       nan       nan ...       nan       nan       nan |
# 	|  9.01e-01    |       nan       nan       nan ...       nan       nan       nan |
# 	|  1.00e+00    |       nan       nan       nan ...       nan       nan       nan |
# 	+==============+=================================================================+
# 	| is_log = True , extrap_orders = (1, 2)                                         |
# 	| HASH_ARRS = 0xe94bc401ffd778d0                                                 |
# 	+==============+=================================================================+ not supported.

# %%
# get C_l's using PyCCL

# build tracers using the emulated_ccl_cosmology
# use single bin data for demonstration
DESI_lens_data_bin1 = np.load("data/DESI_lens_data_bin1.npy")
HSC_dist_0_3_bin1 = np.load("data/HSC_dist_0_3_bin1.npy")

lens_tracers_emu, source_tracers_emu = build_tracers_from_data(
    emulated_ccl_cosmology, DESI_lens_data_bin1, HSC_dist_0_3_bin1)

# define the multipoles (ells) for which to calculate the Cls
ells = np.arange(2, 3000, 1)

# calculate angular power spectra for desired correlation types
correlation_types = ['LL', 'GG', 'GL', 'CC', 'CL', 'CG']
emulated_cls = {}

# calculate the C_l's
def calculate_cls(cosmology, lens_data, source_data, ells, correlation_types):

    lens_tracers, source_tracers = build_tracers_from_data(
        cosmology, lens_data, source_data)

    calculated_cls = {}
    for corr_type in correlation_types:
        if corr_type == 'LL':
            for i in range(len(lens_tracers)):
                for j in range(i, len(lens_tracers)):
                    key = f"CL_{corr_type}{i+1}_{j+1}"
                    calculated_cls[key] = ccl.angular_cl(cosmology, lens_tracers[i], lens_tracers[j], ells)
        elif corr_type == 'GG':
            for i in range(len(source_tracers)):
                for j in range(i, len(source_tracers)):
                    key = f"CL_{corr_type}{i+1}_{j+1}"
                    calculated_cls[key] = ccl.angular_cl(cosmology, source_tracers[i], source_tracers[j], ells)
        elif corr_type == 'GL':
            for i in range(len(source_tracers)):
                for j in range(len(lens_tracers)):
                    key = f"CL_{corr_type}{i+1}_{j+1}"
                    calculated_cls[key] = ccl.angular_cl(cosmology, source_tracers[i], lens_tracers[j], ells)
        elif corr_type == 'CC':
            cmb_kappa_tracer = ccl.CMBLensingTracer(cosmology, z_source=1100)
            calculated_cls['CL_CC1_1'] = ccl.angular_cl(cosmology, cmb_kappa_tracer, cmb_kappa_tracer, ells)
        elif corr_type == 'CL':
            cmb_kappa_tracer = ccl.CMBLensingTracer(cosmology, z_source=1100)
            for i in range(len(lens_tracers)):
                key = f"CL_{corr_type}1_{i+1}"
                calculated_cls[key] = ccl.angular_cl(cosmology, cmb_kappa_tracer, lens_tracers[i], ells)
        elif corr_type == 'CG':
            cmb_kappa_tracer = ccl.CMBLensingTracer(cosmology, z_source=1100)
            for i in range(len(source_tracers)):
                key = f"CL_{corr_type}1_{i+1}"
                calculated_cls[key] = ccl.angular_cl(cosmology, cmb_kappa_tracer, source_tracers[i], ells)
    return calculated_cls

# %%
# plot C_l's

plt.figure(figsize=(10, 6))

# for single bin scenario, we expect CL_LL1_1, CL_GG1_1, CL_GL1_1, CL_CC1_1, CL_CL1_1, CL_CG1_1
if 'CL_LL1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_LL1_1'], label='CL_LL (Lens-Lens)')
if 'CL_GG1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_GG1_1'], label='CL_GG (Source-Source)')
if 'CL_GL1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_GL1_1'], label='CL_GL (Source-Lens)')
if 'CL_CC1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_CC1_1'], label='CL_CC (CMB Lensing Auto)')
if 'CL_CL1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_CL1_1'], label='CL_CL (CMB Lensing-Lens)')
if 'CL_CG1_1' in emulated_cls:
    plt.loglog(ells, emulated_cls['CL_CG1_1'], label='CL_CG (CMB Lensing-Source)')

plt.xlabel('Multipole $\ell$')
plt.ylabel('C$_{\ell}$ (Emulated)')
plt.title('Angular Power Spectra using Emulated P(k)')
plt.legend()
plt.grid(True, which="both", ls="-")
plt.tight_layout()
plt.show()

# %%
# compare standard PyCCL with our new method -- timing

# standard PyCCL
start_time_ccl = time.time()
standard_ccl_cls = calculate_cls(flat_LCDM_cosmology, DESI_lens_data_bin1, HSC_dist_0_3_bin1, ells, correlation_types)
end_time_ccl = time.time()
time_ccl = end_time_ccl - start_time_ccl

# emulated PyCCL
start_time_emu = time.time()

emulated_cls = calculate_cls(
    emulated_ccl_cosmology, DESI_lens_data_bin1, HSC_dist_0_3_bin1, ells, correlation_types)

end_time_emu = time.time()
time_emu = end_time_emu - start_time_emu

print(f"Standard PyCCL Calculation: {time_ccl:.4f} seconds")
print(f"Emulated P(k) PyCCL Calculation: {time_emu:.4f} seconds")
print(f"Emulated P(k) is approximately {time_ccl / time_emu:.2f} times faster than Standard PyCCL (if faster).")

# %%
# compare standard PyCCL with our new method -- plots

plt.figure(figsize=(15, 10))
plot_keys = ['CL_LL1_1', 'CL_GG1_1', 'CL_GL1_1', 'CL_CC1_1', 'CL_CL1_1', 'CL_CG1_1']

for i, key in enumerate(plot_keys):
    if key in standard_ccl_cls and key in emulated_cls:
        plt.subplot(3, 2, i + 1)
        plt.loglog(ells, standard_ccl_cls[key], label=f'Standard CCL {key}', color='blue')
        plt.loglog(ells, emulated_cls[key], label=f'Emulated P(k) CCL {key}', linestyle='--', color='red')
        plt.xlabel('Multipole $\ell$')
        plt.ylabel('C$_{\ell}$ (Emulated vs. Standard)')
        plt.title(f'Comparison for {key}')
        plt.legend()
        plt.grid(True, which="both", ls="-")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cobaya
#
# 1.  **Parameters**: The cosmological parameters we want to constrain (e.g., $\Omega_m$, $\sigma_8$, $h$).
# 2.  **Likelihood**: A Python class that calculates the log-likelihood $L(\mathbf{D}|\mathbf{\theta})$, where $\mathbf{D}$ is the data vector and $\mathbf{\theta}$ are the cosmological parameters. For a Gaussian likelihood, this involves comparing a theoretical model (based on $\mathbf{\theta}$) to an observed data vector (which we'll treat as a fiducial model with noise) and using a covariance matrix.
# 3.  **Prior**: The prior distributions for our parameters.
# 4.  **Sampler**: The MCMC algorithm Cobaya will use to explore the parameter space.
#
# ### Likelihood
#
# $$\ln L = -\frac{1}{2} (\mathbf{D} - \mathbf{M}(\mathbf{\theta}))^T \mathbf{C}^{-1} (\mathbf{D} - \mathbf{M}(\mathbf{\theta})) - \frac{1}{2} \ln |\mathbf{C}|$$
#
# where:
# *   $\mathbf{D}$ is the 'observed' data vector (derived from a fiducial cosmology with noise).
# *   $\mathbf{M}(\mathbf{\theta})$ is the model prediction for the data vector, calculated using the given cosmological parameters $\mathbf{\theta}$.
# *   $\mathbf{C}$ is the covariance matrix.
#
# We already have the infrastructure to build the covariance matrix and calculate the theoretical $C_\ell$ values for a given cosmology. Now, we need to wrap this logic into a Cobaya-compatible likelihood class.

# %% [markdown]
# ### Parameters and Sampler
#
# **Parameters (params section):**
#
# *   **prior**: The prior distribution for the parameter (e.g., min/max for a flat prior, loc/scale for a Gaussian).
# *   **ref**: A reference value, often used by samplers to initiate chains or define a starting point.
# *   **proposal**: The width of the proposal distribution for the sampler (how much the parameter changes in each step).
# *   **latex**: A LaTeX representation for plotting and reporting.
#
# **Sampler (sampler section):**
#
# *   **Rminus1_stop**: A convergence criterion (Gelman-Rubin statistic minus 1). Smaller values indicate better convergence.
# *   **max_samples**: The maximum number of samples to generate.

# %%
# make and save noise and data files for just the first bin

# make sure folder exists
os.makedirs("data", exist_ok=True)

# data
DESI_lens_data_bin1 = DESI_lens_data[:, :2]  # z + first lens bin
HSC_dist_0_3_bin1 = HSC_dist_0_3[:, :2]       # z + first source bin

# noise
DESI_shot_noise_bin1 = np.array([DESI_shot_noise[0]])
DESI_shape_noise_bin1 = np.array([DESI_shape_noise[0]])

# save
np.save("data/DESI_lens_data_bin1.npy", DESI_lens_data_bin1)
np.save("data/HSC_dist_0_3_bin1.npy", HSC_dist_0_3_bin1)
np.save("data/DESI_shot_noise_bin1.npy", DESI_shot_noise_bin1)
np.save("data/DESI_shape_noise_bin1.npy", DESI_shape_noise_bin1)

# check
print("DESI_lens_data_bin1 shape:", DESI_lens_data_bin1.shape)
print("HSC_dist_0_3_bin1 shape:", HSC_dist_0_3_bin1.shape)
print("DESI_shot_noise_bin1:", DESI_shot_noise_bin1)
print("DESI_shape_noise_bin1:", DESI_shape_noise_bin1)
# Out:
# DESI_lens_data_bin1 shape: (293, 2)
# HSC_dist_0_3_bin1 shape: (1000, 2)
# DESI_shot_noise_bin1: [3.71938241e-06]
# DESI_shape_noise_bin1: [2.51430251e-07]

# %%
# calculate and save fiducial data vector and covariance matrix for single bin

# ensure output directory exists
os.makedirs('cobaya_data', exist_ok=True)

print("Calculating fiducial data vector and covariance matrix for single bin...")

# Use explicit parameters for fiducial cosmology, avoiding dependency on info_single_bin
# These values are taken from the 'fiducial_cosmology_params' in the original 'info' dict (cell 93e8009f)
fiducial_cosmology = ccl.Cosmology(
    Omega_c=0.27,
    Omega_b=0.045,
    h=0.674,
    sigma8=0.8,
    n_s=0.96,
    w0=-1.0,
    wa=0.0,
    Omega_k=0.0,
    transfer_function='bbks'
)

# Extract other parameters directly, or hardcode them if they are constant for this generation step
f_sky = 0.4
n_ell = 3000
binsize = 50
magnification_bias_lenses = 0.8
desired_spectra = ['GG', 'LL', 'GL', 'CC', 'CL', 'CG']

# build covariance and spectra dictionary
cov_obj, fiducial_spectra_dict, f_map = \
    build_covariance_from_data(
        fiducial_cosmology,
        DESI_lens_data_bin1,
        HSC_dist_0_3_bin1,
        f_sky=f_sky,
        n_ell=n_ell,
        binsize=binsize,
        shot_noise_lens=DESI_shot_noise_bin1,
        shape_noise_source=DESI_shape_noise_bin1,
        cmb_noise_kappa=SO_CMB_noise, # SO_CMB_noise is already a numpy array
        magnification_bias_lenses=magnification_bias_lenses,
        desired_spectra=desired_spectra
    )

# extract and flatten the fiducial data vector
observed_data_vector = np.array([])
num_binned_ells = int(np.ceil(n_ell / binsize))

for pair in f_map.pairs:
    unbinned_cls = fiducial_spectra_dict[pair]
    binned_cls_for_pair = []
    for i in range(0, n_ell, binsize):
        end_idx = min(i + binsize, len(unbinned_cls))
        if i < end_idx:
            binned_cls_for_pair.append(np.mean(unbinned_cls[i:end_idx]))
        else:
            binned_cls_for_pair.append(0.0)
    while len(binned_cls_for_pair) < num_binned_ells:
        binned_cls_for_pair.append(0.0)
    observed_data_vector = np.concatenate((observed_data_vector, binned_cls_for_pair))

# get the covariance matrix
covariance_matrix = cov_obj.matrix

# Save to files
data_vector_filename = 'cobaya_data/single_bin_data_vector.npy'
covariance_filename = 'cobaya_data/single_bin_covariance_matrix.npy'

np.save(data_vector_filename, observed_data_vector)
np.save(covariance_filename, covariance_matrix)

print(f"Fiducial data vector saved to: {data_vector_filename}")
print(f"Covariance matrix saved to: {covariance_filename}")
# Out:
# Calculating fiducial data vector and covariance matrix for single bin...
# Fiducial data vector saved to: cobaya_data/single_bin_data_vector.npy
# Covariance matrix saved to: cobaya_data/single_bin_covariance_matrix.npy

# %%
# bin1 one param -- omega_m
# have yaml file call these data and niose and covariances files
# then run cobaya!
# single bin single param (omega_m)
yaml_filename = 'bin1_omega_m_likelihood.yaml'
print(f"Running Cobaya sampler from YAML file: {yaml_filename}")
updated_info_from_yaml, sampler_from_yaml = cobaya_run(yaml_filename)
print("Cobaya run from YAML completed.")
# Out:
# Running Cobaya sampler from YAML file: likelihood.yaml
# [output] Output to be read-from/written-into folder 'chains', with prefix 'cobaya_so_x_desi_forecast_single_bin'
# Initializing SO_x_DESI_Likelihood...
#   Loaded lens data from data/DESI_lens_data_bin1.npy
#   Loaded source data from: data/HSC_dist_0_3_bin1.npy
#   Loading observed data vector from: cobaya_data/single_bin_data_vector.npy
#   Loading covariance matrix from: cobaya_data/single_bin_covariance_matrix.npy
# SO_x_DESI_Likelihood initialized successfully.
# [mcmc] *WARNING* This run has been SEEDED with seed 12345
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Omega_m:0.3
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {functions_and_classes.SO_x_DESI_Likelihood: 0.231}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2026-05-05 16:22:23 : 1 steps taken, and 0 accepted.
# [mcmc] Progress @ 2026-05-05 16:23:23 : 15 steps taken, and 3 accepted.
# [mcmc] Progress @ 2026-05-05 16:24:24 : 29 steps taken, and 5 accepted.
# [mcmc] Progress @ 2026-05-05 16:25:29 : 44 steps taken, and 7 accepted.
# [mcmc] Progress @ 2026-05-05 16:26:33 : 59 steps taken, and 11 accepted.
# [mcmc] Progress @ 2026-05-05 16:27:33 : 73 steps taken, and 15 accepted.
# [mcmc] Progress @ 2026-05-05 16:28:33 : 87 steps taken, and 16 accepted.
# [mcmc] Progress @ 2026-05-05 16:29:37 : 102 steps taken, and 20 accepted.
# [mcmc] Progress @ 2026-05-05 16:30:41 : 117 steps taken, and 22 accepted.
# [mcmc] Progress @ 2026-05-05 16:31:45 : 132 steps taken, and 25 accepted.
# [mcmc] Progress @ 2026-05-05 16:32:46 : 146 steps taken, and 26 accepted.
# [mcmc] Progress @ 2026-05-05 16:33:47 : 160 steps taken, and 27 accepted.
# [mcmc] Progress @ 2026-05-05 16:34:47 : 174 steps taken, and 31 accepted.
# [mcmc] Progress @ 2026-05-05 16:35:48 : 188 steps taken, and 33 accepted.
# [mcmc] Progress @ 2026-05-05 16:36:51 : 202 steps taken, and 37 accepted.
# [mcmc] Progress @ 2026-05-05 16:37:51 : 216 steps taken, and 39 accepted.
# [mcmc] Learn + convergence test @ 40 samples accepted.
# [mcmc]  - Acceptance rate: 0.185
# [mcmc]  - Convergence of means: R-1 = 0.449565 after 32 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 16:38:55 : 231 steps taken, and 47 accepted.
# [mcmc] Progress @ 2026-05-05 16:39:55 : 245 steps taken, and 59 accepted.
# [mcmc] Progress @ 2026-05-05 16:40:56 : 259 steps taken, and 69 accepted.
# [mcmc] Progress @ 2026-05-05 16:41:56 : 273 steps taken, and 79 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.268290 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 16:42:56 : 287 steps taken, and 90 accepted.
# [mcmc] Progress @ 2026-05-05 16:43:57 : 301 steps taken, and 99 accepted.
# [mcmc] Progress @ 2026-05-05 16:44:57 : 315 steps taken, and 109 accepted.
# [mcmc] Progress @ 2026-05-05 16:45:58 : 329 steps taken, and 115 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.449
# [mcmc]  - Convergence of means: R-1 = 0.111112 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 16:46:59 : 343 steps taken, and 123 accepted.
# [mcmc] Progress @ 2026-05-05 16:47:59 : 357 steps taken, and 132 accepted.
# [mcmc] Progress @ 2026-05-05 16:49:00 : 371 steps taken, and 139 accepted.
# [mcmc] Progress @ 2026-05-05 16:50:00 : 385 steps taken, and 146 accepted.
# [mcmc] Progress @ 2026-05-05 16:51:01 : 399 steps taken, and 158 accepted.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.559
# [mcmc]  - Convergence of means: R-1 = 0.134170 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 16:52:01 : 413 steps taken, and 168 accepted.
# [mcmc] Progress @ 2026-05-05 16:53:02 : 427 steps taken, and 176 accepted.
# [mcmc] Progress @ 2026-05-05 16:54:06 : 442 steps taken, and 185 accepted.
# [mcmc] Progress @ 2026-05-05 16:55:06 : 456 steps taken, and 194 accepted.
# [mcmc] Learn + convergence test @ 200 samples accepted.
# [mcmc]  - Acceptance rate: 0.656
# [mcmc]  - Convergence of means: R-1 = 0.103115 after 160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 16:56:07 : 470 steps taken, and 203 accepted.
# [mcmc] Progress @ 2026-05-05 16:57:07 : 484 steps taken, and 211 accepted.
# [mcmc] Progress @ 2026-05-05 16:58:08 : 498 steps taken, and 219 accepted.
# [mcmc] Progress @ 2026-05-05 16:59:08 : 512 steps taken, and 226 accepted.
# [mcmc] Progress @ 2026-05-05 17:00:09 : 526 steps taken, and 237 accepted.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.644
# [mcmc]  - Convergence of means: R-1 = 0.039218 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:01:12 : 541 steps taken, and 246 accepted.
# [mcmc] Progress @ 2026-05-05 17:02:16 : 556 steps taken, and 255 accepted.
# [mcmc] Progress @ 2026-05-05 17:03:17 : 570 steps taken, and 265 accepted.
# [mcmc] Progress @ 2026-05-05 17:04:17 : 584 steps taken, and 274 accepted.
# [mcmc] Learn + convergence test @ 280 samples accepted.
# [mcmc]  - Acceptance rate: 0.631
# [mcmc]  - Convergence of means: R-1 = 0.021017 after 224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:05:18 : 598 steps taken, and 281 accepted.
# [mcmc] Progress @ 2026-05-05 17:06:18 : 612 steps taken, and 289 accepted.
# [mcmc] Progress @ 2026-05-05 17:07:20 : 626 steps taken, and 297 accepted.
# [mcmc] Progress @ 2026-05-05 17:08:24 : 641 steps taken, and 308 accepted.
# [mcmc] Progress @ 2026-05-05 17:09:28 : 656 steps taken, and 318 accepted.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.626
# [mcmc]  - Convergence of means: R-1 = 0.053432 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:10:28 : 670 steps taken, and 325 accepted.
# [mcmc] Progress @ 2026-05-05 17:11:29 : 684 steps taken, and 337 accepted.
# [mcmc] Progress @ 2026-05-05 17:12:29 : 698 steps taken, and 345 accepted.
# [mcmc] Progress @ 2026-05-05 17:13:30 : 712 steps taken, and 350 accepted.
# [mcmc] Progress @ 2026-05-05 17:14:34 : 727 steps taken, and 360 accepted.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.621
# [mcmc]  - Convergence of means: R-1 = 0.010927 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:15:38 : 742 steps taken, and 366 accepted.
# [mcmc] Progress @ 2026-05-05 17:16:41 : 757 steps taken, and 372 accepted.
# [mcmc] Progress @ 2026-05-05 17:17:45 : 772 steps taken, and 378 accepted.
# [mcmc] Progress @ 2026-05-05 17:18:49 : 787 steps taken, and 385 accepted.
# [mcmc] Progress @ 2026-05-05 17:19:53 : 802 steps taken, and 396 accepted.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.599
# [mcmc]  - Convergence of means: R-1 = 0.013856 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:20:57 : 816 steps taken, and 404 accepted.
# [mcmc] Progress @ 2026-05-05 17:21:59 : 830 steps taken, and 412 accepted.
# [mcmc] Progress @ 2026-05-05 17:23:02 : 844 steps taken, and 419 accepted.
# [mcmc] Progress @ 2026-05-05 17:24:05 : 858 steps taken, and 430 accepted.
# [mcmc] Progress @ 2026-05-05 17:25:07 : 872 steps taken, and 440 accepted.
# [mcmc] Learn + convergence test @ 440 samples accepted.
# [mcmc]  - Acceptance rate: 0.598
# [mcmc]  - Convergence of means: R-1 = 0.011873 after 352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:26:08 : 886 steps taken, and 447 accepted.
# [mcmc] Progress @ 2026-05-05 17:27:12 : 901 steps taken, and 456 accepted.
# [mcmc] Progress @ 2026-05-05 17:28:12 : 915 steps taken, and 462 accepted.
# [mcmc] Progress @ 2026-05-05 17:29:16 : 930 steps taken, and 471 accepted.
# [mcmc] Progress @ 2026-05-05 17:30:19 : 945 steps taken, and 478 accepted.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.588
# [mcmc]  - Convergence of means: R-1 = 0.031265 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:31:21 : 959 steps taken, and 487 accepted.
# [mcmc] Progress @ 2026-05-05 17:32:21 : 973 steps taken, and 494 accepted.
# [mcmc] Progress @ 2026-05-05 17:33:21 : 987 steps taken, and 500 accepted.
# [mcmc] Progress @ 2026-05-05 17:34:21 : 1001 steps taken, and 511 accepted.
# [mcmc] Progress @ 2026-05-05 17:35:21 : 1015 steps taken, and 517 accepted.
# [mcmc] Learn + convergence test @ 520 samples accepted.
# [mcmc]  - Acceptance rate: 0.587
# [mcmc]  - Convergence of means: R-1 = 0.004667 after 416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2026-05-05 17:36:25 : 1030 steps taken, and 527 accepted.
# [mcmc] Progress @ 2026-05-05 17:37:30 : 1045 steps taken, and 536 accepted.
# [mcmc] Progress @ 2026-05-05 17:38:30 : 1059 steps taken, and 545 accepted.
# [mcmc] Progress @ 2026-05-05 17:39:30 : 1073 steps taken, and 552 accepted.
# [mcmc] Progress @ 2026-05-05 17:40:30 : 1087 steps taken, and 557 accepted.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.580
# [mcmc]  - Convergence of means: R-1 = 0.007958 after 448 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.100444 after 560 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 560 accepted steps.
# Cobaya run from YAML completed.

# %%
# plot distribution

# distribution
samples = loadMCSamples("chains/cobaya_so_x_desi_forecast_bin1_omega_m")

g = plots.get_subplot_plotter()
g.plot_1d(samples, 'Omega_m')
ax = plt.gca()
ax.axvline(x=0.315, color='blue', linestyle='--', linewidth=1)
print("MCMC reference Omega_m was given as 0.3, though DESI has it as .316. In future runs we will use .316.")
print("Note that it finds that value anyway!")
# Out:
# MCMC reference Omega_m was given as 0.3, though DESI has it as .316. In future runs we will use .316.
# Note that it finds that value anyway!

# %%
# trace
chain = np.loadtxt("chains/cobaya_so_x_desi_forecast_bin1_omega_m.1.txt")

omega_m = chain[:, 2]  # adjust index if Omega_m isn't first column

burn = int(0.2 * len(omega_m))
plt.plot(omega_m[burn:], alpha=0.3, linewidth=0.75)
plt.xlabel("Step")
plt.ylabel("Omega_m")
plt.show()
plt.show()

# %%
# load chains (prefix only)
chain_output_path = 'chains/cobaya_so_x_desi_forecast_bin1_omega_m'
samples = loadMCSamples(chain_output_path)

# find available parameters
param_infos = samples.getParamNames().names
param_names = [p.name for p in param_infos]

print("All parameters in chain:")
print(param_names)

# cosmology parameters
cosmo_params = ['Omega_m']

# keep only ones that actually exist in the chain
cosmo_params = [p for p in cosmo_params if p in param_names]

# make triangle plot
g = plots.get_subplot_plotter(width_inch=10)
g.triangle_plot(samples, params=cosmo_params, filled=True, linewidth=1, color='black')

plt.suptitle("Cosmology parameter constraints", fontsize=14)
plt.show()

print("MCMC reference Omega_m was given as 0.3, though DESI has it as .316. In future runs we will use .316.")
print("Note that it finds that value anyway!")
# Out:
# All parameters in chain:
# ['Omega_m', 'minuslogprior', 'minuslogprior__0', 'chi2', 'chi2__functions_and_classes.SO_x_DESI_Likelihood']
# MCMC reference Omega_m was given as 0.3, though DESI has it as .316. In future runs we will use .316.
# Note that it finds that value anyway!

# %%
# bin1 one param, uniform prior, 4 chains

# %%
# bin1 two parameters (omega_m and sigma_8)
# make a new likelihood yaml for this, but use the same data and covariance
yaml_filename = 'bin1_omega_m_sigma_8_likelihood.yaml'
print(f"Running Cobaya sampler from YAML file: {yaml_filename}")
updated_info_from_yaml, sampler_from_yaml = cobaya_run(yaml_filename)
print("Cobaya run from YAML completed.")

# %%
g = plots.get_subplot_plotter(width_inch=10)
g.settings.tight_layout = False  # Prevent the crash during layout adjustment
g.triangle_plot(samples, params=cosmo_params, filled=True)

# plot corner plot

# load chains
chain_output_path = 'chains/cobaya_so_x_desi_forecast_bin1_omega_m_sigma_8'
samples = loadMCSamples(chain_output_path)

# find available
param_infos = samples.getParamNames().names
param_names = [p.name for p in param_infos]

print("All parameters in chain:")
print(param_names)

# cosmology parameters (edit to match your run) ---
cosmo_params = ['Omega_m', 'sigma8']

# keep only ones that actually exist in the chain
cosmo_params = [p for p in cosmo_params if p in param_names]

# make triangle plot
g = plots.get_subplot_plotter(width_inch=10)
g.triangle_plot(samples, params=cosmo_params, filled=True)

plt.suptitle("Cosmology parameter constraints", fontsize=14)
plt.show()

# %%
# plot traces

chain = np.loadtxt("chains/cobaya_so_x_desi_forecast_bin1_omega_m_sigma_8.1.txt")
omega_m = chain[:, 2]
sigma_8 = chain[:, 3] # adjust index based on your param_names order

# burn-in
burn = int(0.0 * len(chain))

# plot
fig, axes = plt.subplots(2, 1, figsize=(10, 6), sharex=True)

# Trace for Omega_m
axes[0].plot(omega_m[burn:], color='steelblue', alpha=0.7, linewidth=0.5)
axes[0].set_ylabel(r"$\Omega_m$")
axes[0].axhline(np.mean(omega_m[burn:]), color='red', linestyle='--', alpha=0.5)

# Trace for sigma_8
axes[1].plot(sigma_8[burn:], color='darkorange', alpha=0.7, linewidth=0.5)
axes[1].set_ylabel(r"$\sigma_8$")
axes[1].set_xlabel("Step (after burn-in)")
axes[1].axhline(np.mean(sigma_8[burn:]), color='red', linestyle='--', alpha=0.5)

plt.suptitle("MCMC Traces")
plt.tight_layout()
plt.show()

# %%
print("hello")
# Out:
# hello

# %%
# test commit
